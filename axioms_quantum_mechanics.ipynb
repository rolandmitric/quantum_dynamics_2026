# %% [markdown]
# # Axioms of Quantum Mechanics
#
# Here, we summarize the basic axioms of  quantum mechanics in the pure-state formulation. Unless stated otherwise, systems are assumed to be closed and measurements are ideal projective measurements.
#
# <strong>Axiom I (Quantum State Space):</strong><br><br>
# The state of a quantum system is represented by a unit vector in a complex Hilbert space $\mathcal{H}$.
#
# Each physical (pure) state corresponds to a ray in $ \mathcal{H}$, i.e., a one-dimensional subspace spanned by a unit vector $ |\psi\rangle \in \mathcal{H} $.
#
# This implies that two state vectors differing only by a global phase factor represent the same physical state. That is, $|\psi\rangle$ and $e^{i\theta}|\psi\rangle$, with $\theta \in \mathbb{R}$, correspond to the same state.

# %% [markdown]
# <strong>Axiom II (Quantum Dynamics):</strong><br><br>
#   The time evolution of a closed quantum system is governed by a unitary transformation. If the system is in state $|\psi(t_0)\rangle$ at time $t_0$, its state at a later time $t$ is given by
#
# $$
#   |\psi(t)\rangle = U(t, t_0)|\psi(t_0)\rangle,
# $$
#
#   where $U(t, t_0)$ is a unitary operator on $\mathcal{H}$.

# %% [markdown]
# <strong>Axiom III (Observables):</strong><br><br>
#
# A measurable quantity is represented by a self-adjoint (Hermitian) operator $A$ on the Hilbert space $\mathcal{H}$:
#
# $$
# A = A^\dagger.
# $$
#
# The possible measurement outcomes are eigenvalues of $A$. In the discrete case one may write the spectral decomposition
#
# $$
# A = \sum_k a_k P_k,
# $$
#
# where the eigenvalues $a_k \in \mathbb{R}$ and the operators $P_k$ are orthogonal projectors satisfying
#
# $$
# P_k^2 = P_k, \qquad P_k^\dagger = P_k, \qquad P_jP_k = \delta_{jk}P_k, \qquad \sum_k P_k = I.
# $$

# %% [markdown]
# <strong>Axiom IV (Measurement Postulate / Born Rule):</strong><br><br>
#
# Let $A = \sum_k a_k P_k$ be an observable and let the system be in a normalized state $|\psi\rangle$. Then the probability of obtaining the outcome $a_k$ is
#
# $$
# p(k) = \langle \psi | P_k | \psi \rangle = \|P_k|\psi\rangle\|^2.
# $$
#
# If the outcome $a_k$ is obtained, then immediately after the measurement the state is projected onto the corresponding eigensubspace:
#
# $$
# |\psi\rangle_{\text{after}} = \frac{P_k|\psi\rangle}{\|P_k|\psi\rangle\|}.
# $$
#
# The expectation value of the observable $A$ in the state $|\psi\rangle$ is therefore
#
# $$
# \langle A \rangle = \langle \psi | A | \psi \rangle.
# $$

# %% [markdown]
# <strong>Axiom V (Composite Systems):</strong><br><br>
#
# If two quantum systems with Hilbert spaces $\mathcal{H}_A$ and $\mathcal{H}_B$ are combined, then the Hilbert space of the composite system is the tensor product
#
# $$
# \mathcal{H}_{AB} = \mathcal{H}_A \otimes \mathcal{H}_B.
# $$
#
# Product states have the form $|\psi_A\rangle \otimes |\phi_B\rangle$, but in general the superposition principle allows states that cannot be written in this factorized form. Such states are called entangled.
#
# Observables acting only on subsystem $A$ are represented by operators of the form $A \otimes I_B$, while observables acting only on subsystem $B$ are represented by $I_A \otimes B$.
#
# > Remark: This is the traditional pure-state, projective-measurement formulation of quantum mechanics. For mixed states, open-system dynamics, and generalized measurements, one extends the formalism to density operators, completely positive trace-preserving maps, and POVMs.
